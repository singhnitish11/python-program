# %% [markdown]
# **Add the two number program code in python**

# %%
#Add the two number program code in python
# Add two numbers

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
sum = num1 + num2

print("The sum of", num1, "and", num2, "is:", sum)

# %% [markdown]
# Add the two number program code in python
